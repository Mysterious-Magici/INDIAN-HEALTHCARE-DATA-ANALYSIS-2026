# %%
import numpy as mp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('New_India_Healthcare_Data_2026.csv')

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'State', 'Socioeconomic_Status',
#        'Occupation', 'Visit_Date', 'Symptoms', 'Primary_Diagnosis',
#        'Fasting_Blood_Glucose__mg_dl', 'Glycemic_Status', 'HbA1c_mmol_mol',
#        'Total_Cholesterol_mg_dL', 'Treatment_Type', 'Treatment_Outcome',
#        'Imaging Type', 'Imaging Findings', 'Hospital Type',
#        'Insurance Covered', 'BMI (kg meter square)', 'BMI Status', 'Age Group',
#        'Visit Year', 'Visit Month', 'Symptom Blurred Vision',
#        'Symptom Chest Pain', 'Symptom Cough', 'Symptom Fatigue',
#        'Symptom Fever', 'Symptom Frequent Urination', 'Symptom Headache',
#        'Symptom High Bp', 'Symptom High Fever', 'Symptom Increased Thirst',
#        'Symptom Joint Pain', 'Symptom Night Sweats',
#        'Symptom Shortness Of Breath', 'Symptom Swelling In Legs',
#        'Symptom Weight Loss'],
#       dtype='object')

# %%
hba1c_count = df["HbA1c_mmol_mol"].value_counts().sort_index()
print(hba1c_count)
ax = hba1c_count.plot(kind="bar", figsize=(8, 5))
for container in ax.containers:
 for container in ax.containers:
    ax.bar_label(container)
plt.title("Distribution of HbA1c")
plt.xlabel("HbA1c (mmol/mol)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# HbA1c_mmol_mol
# 31.2    21871
# 38.8    17863
# 47.5    20720
# 63.9    23044
# 85.5    12183
# 85.8     4319
# Name: count, dtype: int64

# %%
year_count = df['Visit Year'].value_counts().sort_index()
print(year_count)
bx = year_count.plot(kind='bar', figsize=(8, 5))
for container in bx.containers:
    bx.bar_label(container)
plt.title('Healthcare Visits by Year')
plt.xlabel('Visit Year')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Visit Year
# 2024    29966
# 2025    49822
# 2026    20212
# Name: count, dtype: int64

# %%
month_count = df['Visit Month'].value_counts().sort_index()
print(month_count)
cx = month_count.plot(kind='line', marker='o', figsize=(9, 5))
for container in cx.containers:
    cx.bar_label(container)
plt.title('Monthly Healthcare Visits')
plt.xlabel('Visit Month')
plt.ylabel('Count')
plt.xticks(range(1, 13))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Visit Month
# 1     8479
# 2     7650
# 3     8434
# 4     8242
# 5     8594
# 6     8212
# 7     8540
# 8     8547
# 9     8136
# 10    8613
# 11    8117
# 12    8436
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'State', 'Socioeconomic_Status',
#        'Occupation', 'Visit_Date', 'Symptoms', 'Primary_Diagnosis',
#        'Fasting_Blood_Glucose__mg_dl', 'Glycemic_Status', 'HbA1c_mmol_mol',
#        'Total_Cholesterol_mg_dL', 'Treatment_Type', 'Treatment_Outcome',
#        'Imaging Type', 'Imaging Findings', 'Hospital Type',
#        'Insurance Covered', 'BMI (kg meter square)', 'BMI Status', 'Age Group',
#        'Visit Year', 'Visit Month', 'Symptom Blurred Vision',
#        'Symptom Chest Pain', 'Symptom Cough', 'Symptom Fatigue',
#        'Symptom Fever', 'Symptom Frequent Urination', 'Symptom Headache',
#        'Symptom High Bp', 'Symptom High Fever', 'Symptom Increased Thirst',
#        'Symptom Joint Pain', 'Symptom Night Sweats',
#        'Symptom Shortness Of Breath', 'Symptom Swelling In Legs',
#        'Symptom Weight Loss'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))

corr = df[['Age','Fasting_Blood_Glucose__mg_dl', 'HbA1c_mmol_mol',
       'Total_Cholesterol_mg_dL', 'BMI (kg meter square)',
       'Visit Year', 'Visit Month',]].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df_cleaned = df.copy()

# %%
df_cleaned.head()
# Out:
#      Patient_ID  Age  Gender           State Socioeconomic_Status  \
# 0  21D74F65-E20   53  Female  Andhra Pradesh                  Low
# 1  0BCF80B5-312   36    Male      Puducherry                  Low
# 2  5EF60C7B-8E6   28    Male     Maharashtra                  Low
# 3  93959ACB-8BA   34  Female       Karnataka                  Low
# 4  B11DB540-128   48  Female      Puducherry                 High
#
#                     Occupation  Visit_Date  \
# 0      Agricultural Consultant  18-09-2025
# 1                Haematologist  14-11-2024
# 2       Financial Risk Analyst  20-02-2026
# 3  Clinical Research Associate  04-11-2025
# 4      Agricultural Consultant  15-08-2025
#
#                              Symptoms       Primary_Diagnosis  \
# 0    Fever, Fatigue, Increased Thirst                  Dengue
# 1           Swelling In Legs, High Bp                 Malaria
# 2    Fever, Fatigue, Increased Thirst            Hypertension
# 3    Fever, Fatigue, Increased Thirst  Cardiovascular Disease
# 4  Frequent Urination, Blurred Vision            Hypertension
#
#    Fasting_Blood_Glucose__mg_dl  ... Symptom Frequent Urination  \
# 0                         100.9  ...                          0
# 1                         121.3  ...                          0
# 2                          74.7  ...                          0
# 3                         102.7  ...                          0
# 4                          70.0  ...                          1
#
#    Symptom Headache  Symptom High Bp Symptom High Fever  \
# 0                 0                0                  0
# 1                 0                1                  0
# 2                 0                0                  0
# 3                 0                0                  0
# 4                 0                0                  0
#
#   Symptom Increased Thirst Symptom Joint Pain Symptom Night Sweats  \
# 0                        1                  0                    0
# 1                        0                  0                    0
# 2                        1                  0                    0
# 3                        1                  0                    0
# 4                        0                  0                    0
#
#   Symptom Shortness Of Breath Symptom Swelling In Legs  Symptom Weight Loss
# 0                           0                        0                    0
# 1                           0                        1                    0
# 2                           0                        0                    0
# 3                           0                        0                    0
# 4                           0                        0                    0
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (100000, 39)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (100000, 39)

# %%
df.isnull().sum()
# Out:
# Patient_ID                      0
# Age                             0
# Gender                          0
# State                           0
# Socioeconomic_Status            0
# Occupation                      0
# Visit_Date                      0
# Symptoms                        0
# Primary_Diagnosis               0
# Fasting_Blood_Glucose__mg_dl    0
# Glycemic_Status                 0
# HbA1c_mmol_mol                  0
# Total_Cholesterol_mg_dL         0
# Treatment_Type                  0
# Treatment_Outcome               0
# Imaging Type                    0
# Imaging Findings                0
# Hospital Type                   0
# Insurance Covered               0
# BMI (kg meter square)           0
# BMI Status                      0
# Age Group                       0
# Visit Year                      0
# Visit Month                     0
# Symptom Blurred Vision          0
# Symptom Chest Pain              0
# Symptom Cough                   0
# Symptom Fatigue                 0
# Symptom Fever                   0
# Symptom Frequent Urination      0
# Symptom Headache                0
# Symptom High Bp                 0
# Symptom High Fever              0
# Symptom Increased Thirst        0
# Symptom Joint Pain              0
# Symptom Night Sweats            0
# Symptom Shortness Of Breath     0
# Symptom Swelling In Legs        0
# Symptom Weight Loss             0
# dtype: int64

# %%
df_cleaned['Gender'].value_counts()
# Out:
# Gender
# Male      51013
# Female    48494
# Other       493
# Name: count, dtype: int64

# %%
df_cleaned['Gender']=df_cleaned['Gender'].map({"Male":0, "Female":1, "Other":3})

# %%
df_cleaned.head()
# Out:
#      Patient_ID  Age  Gender           State Socioeconomic_Status  \
# 0  21D74F65-E20   53       1  Andhra Pradesh                  Low
# 1  0BCF80B5-312   36       0      Puducherry                  Low
# 2  5EF60C7B-8E6   28       0     Maharashtra                  Low
# 3  93959ACB-8BA   34       1       Karnataka                  Low
# 4  B11DB540-128   48       1      Puducherry                 High
#
#                     Occupation  Visit_Date  \
# 0      Agricultural Consultant  18-09-2025
# 1                Haematologist  14-11-2024
# 2       Financial Risk Analyst  20-02-2026
# 3  Clinical Research Associate  04-11-2025
# 4      Agricultural Consultant  15-08-2025
#
#                              Symptoms       Primary_Diagnosis  \
# 0    Fever, Fatigue, Increased Thirst                  Dengue
# 1           Swelling In Legs, High Bp                 Malaria
# 2    Fever, Fatigue, Increased Thirst            Hypertension
# 3    Fever, Fatigue, Increased Thirst  Cardiovascular Disease
# 4  Frequent Urination, Blurred Vision            Hypertension
#
#    Fasting_Blood_Glucose__mg_dl  ... Symptom Frequent Urination  \
# 0                         100.9  ...                          0
# 1                         121.3  ...                          0
# 2                          74.7  ...                          0
# 3                         102.7  ...                          0
# 4                          70.0  ...                          1
#
#    Symptom Headache  Symptom High Bp Symptom High Fever  \
# 0                 0                0                  0
# 1                 0                1                  0
# 2                 0                0                  0
# 3                 0                0                  0
# 4                 0                0                  0
#
#   Symptom Increased Thirst Symptom Joint Pain Symptom Night Sweats  \
# 0                        1                  0                    0
# 1                        0                  0                    0
# 2                        1                  0                    0
# 3                        1                  0                    0
# 4                        0                  0                    0
#
#   Symptom Shortness Of Breath Symptom Swelling In Legs  Symptom Weight Loss
# 0                           0                        0                    0
# 1                           0                        1                    0
# 2                           0                        0                    0
# 3                           0                        0                    0
# 4                           0                        0                    0
#
# [5 rows x 39 columns]

# %%
target = 'Treatment_Outcome'
X = df.drop('Treatment_Outcome', axis=1)
y = df['Treatment_Outcome']

# %%
X = X.drop(columns=['Patient_ID'], errors='ignore')

# %%
numerical_features = X.select_dtypes(
    include=['int64', 'float64']
).columns

categorical_features = X.select_dtypes(
    include=['object', 'category']
).columns

# %%
numerical_features
# Out:
# Index(['Age', 'Fasting_Blood_Glucose__mg_dl', 'HbA1c_mmol_mol',
#        'Total_Cholesterol_mg_dL', 'BMI (kg meter square)', 'Visit Year',
#        'Visit Month', 'Symptom Blurred Vision', 'Symptom Chest Pain',
#        'Symptom Cough', 'Symptom Fatigue', 'Symptom Fever',
#        'Symptom Frequent Urination', 'Symptom Headache', 'Symptom High Bp',
#        'Symptom High Fever', 'Symptom Increased Thirst', 'Symptom Joint Pain',
#        'Symptom Night Sweats', 'Symptom Shortness Of Breath',
#        'Symptom Swelling In Legs', 'Symptom Weight Loss'],
#       dtype='object')

# %%
categorical_features
